# %%
##-----Library Imports------##
import pandas as pd
import matplotlib as plt
import numpy as np
# %matplotlib inline
from matplotlib import pyplot
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from datetime import datetime

# %%
##--Set parameters for dataset--##
remove_outliers =0

# %%
##-----STEP ONE: Import Data-----##

data_path = "./Data/2019/December/listings_complete.csv"
df = pd.read_csv(data_path)

pd.set_option('display.max_columns', None)

print("The first 5 rows of the dataframe") 
df.head(5)
# Out:
# The first 5 rows of the dataframe
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (43,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       id                         listing_url       scrape_id last_scraped  \
# 0   3191   https://www.airbnb.com/rooms/3191  20191228152823   2019-12-28
# 1  13044  https://www.airbnb.com/rooms/13044  20191228152823   2019-12-29
# 2  15007  https://www.airbnb.com/rooms/15007  20191228152823   2019-12-29
# 3  15077  https://www.airbnb.com/rooms/15077  20191228152823   2019-12-28
# 4  15180  https://www.airbnb.com/rooms/15180  20191228152823   2019-12-29
#
#                                 name  \
# 0            Malleson Garden Cottage
# 1     JAMBO Guest House / Green Room
# 2                   Blaauwberg House
# 3  Top relaxed beach living in style
# 4          The Melkbaai - Beachfront
#
#                                              summary  \
# 0  This is a lovely, separate, self-catering cott...
# 1  The Green Room at Jambo Guest House is a sligh...
# 2  Welcome to our self-catering beach-front famil...
# 3  Situated either on the ground floor with direc...
# 4                                                NaN
#
#                                                space  \
# 0  Beautiful self catering luxury cottage in cent...
# 1  Jambo, which means hello in Swahili, is a gues...
# 2  The house sleeps 6 and has all necessary ameni...
# 3  A stunning architect designed guesthouse, Suns...
# 4  Self Catering Holiday Apartments available for...
#
#                                          description experiences_offered  \
# 0  This is a lovely, separate, self-catering cott...                none
# 1  The Green Room at Jambo Guest House is a sligh...                none
# 2  Welcome to our self-catering beach-front famil...                none
# 3  Situated either on the ground floor with direc...                none
# 4  Self Catering Holiday Apartments available for...                none
#
#                                neighborhood_overview  \
# 0  Mowbray is on the Southern Suburbs line, 6km (...
# 1  Green Point is a popular leisure district domi...
# 2  Bloubergstrand is a lovely, cosy suburb near C...
# 3  It is probably the best hub in order to explor...
# 4  Apartment is located in Beach Road, Strand, We...
#
#                                                notes  \
# 0  There are pets on the property. One cat, who w...
# 1  Very centrally situated and walking distance t...
# 2  Please note we do not provide beach towels at ...
# 3  USEFUL TIPS BEFORE ARRIVAL.. There is a Nespre...
# 4  Please note the apartment is on the second flo...
#
#                                              transit  \
# 0  The train station is about 400m from the cotta...
# 1  A lot of big attractions are within walking di...
# 2  We're located about 25 minutes drive out on th...
# 3  The city bus (Website hidden by Airbnb)  is ab...
# 4  Local taxi's (Strand Taxi) can be booked to ge...
#
#                                               access  \
# 0  Fully self-contained cottage with separate ent...
# 1  Guests will have access to their own private r...
# 2  Guests have access to the full self-catering h...
# 3        You live in a guesthouse without limits :-)
# 4       The apartment is rented as a unit per night.
#
#                                          interaction  \
# 0  I live in the main house on the property, and ...
# 1  Barry and Mina will be around to ensure you ha...
# 2  Ingrid, our booking manager, will meet you and...
# 3  Either I am in the house living as well and if...
# 4  You are welcome to contact the hosts 24 hours ...
#
#                                          house_rules  thumbnail_url  \
# 0  There is no smoking in the cottage, but you ca...            NaN
# 1  We expect our guests to be well behaved. Only ...            NaN
# 2  Please ensure that arrangements are made for y...            NaN
# 3  The pool is unsupervised – guests are advised ...            NaN
# 4  Guests must just adhere to the normal rules th...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/697022/385...
# 1         NaN  https://a0.muscache.com/im/pictures/1a1dd4ee-4...
# 2         NaN  https://a0.muscache.com/im/pictures/3b654aa4-2...
# 3         NaN  https://a0.muscache.com/im/pictures/4a8fceaa-6...
# 4         NaN  https://a0.muscache.com/im/pictures/e679464f-f...
#
#    xl_picture_url  host_id                                 host_url  \
# 0             NaN     3754   https://www.airbnb.com/users/show/3754
# 1             NaN    50700  https://www.airbnb.com/users/show/50700
# 2             NaN    59072  https://www.airbnb.com/users/show/59072
# 3             NaN    59342  https://www.airbnb.com/users/show/59342
# 4             NaN    59663  https://www.airbnb.com/users/show/59663
#
#       host_name  host_since                          host_location  \
# 0      Brigitte  2008-10-21  Cape Town, Western Cape, South Africa
# 1  Barry & Mina  2009-11-02  Cape Town, Western Cape, South Africa
# 2          Dirk  2009-12-01  Cape Town, Western Cape, South Africa
# 3         Georg  2009-12-02                              Gibraltar
# 4        Heinri  2009-12-03  Cape Town, Western Cape, South Africa
#
#                                           host_about host_response_time  \
# 0  I'm single and love to travel and meeting peop...     within an hour
# 1  We have been running multi Award Winning Jambo...     within an hour
# 2  Proud to live in the beautiful city of Cape To...     within an hour
# 3           challenge us please! we love to perform!     within an hour
# 4                                                NaN                NaN
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 t
# 1               100%                   NaN                 f
# 2               100%                   NaN                 t
# 3               100%                   NaN                 f
# 4                NaN                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/3754/profile_...
# 1  https://a0.muscache.com/im/users/50700/profile...
# 2  https://a0.muscache.com/im/pictures/user/86c72...
# 3  https://a0.muscache.com/im/users/59342/profile...
# 4  https://a0.muscache.com/defaults/user_pic-50x5...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/3754/profile_...                NaN
# 1  https://a0.muscache.com/im/users/50700/profile...                NaN
# 2  https://a0.muscache.com/im/pictures/user/86c72...                NaN
# 3  https://a0.muscache.com/im/users/59342/profile...                NaN
# 4  https://a0.muscache.com/defaults/user_pic-225x...                NaN
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  5.0                        5.0
# 2                 12.0                       12.0
# 3                  5.0                        5.0
# 4                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 1            ['email', 'phone', 'reviews', 'selfie']                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4                                 ['email', 'phone']                    f
#
#   host_identity_verified                                        street  \
# 0                      t  Southern Suburbs, Western Cape, South Africa
# 1                      f         Cape Town, Western Cape, South Africa
# 2                      t         Cape Town, Western Cape, South Africa
# 3                      t         Cape Town, Western Cape, South Africa
# 4                      f         Cape Town, Western Cape, South Africa
#
#    neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed  \
# 0            NaN                Ward 57                           NaN
# 1            NaN               Ward 115                           NaN
# 2            NaN                Ward 23                           NaN
# 3            NaN                 Ward 4                           NaN
# 4            NaN                Ward 83                           NaN
#
#                city         state zipcode     market  \
# 0  Southern Suburbs  Western Cape    7700  Cape Town
# 1         Cape Town  Western Cape    8051  Cape Town
# 2         Cape Town  Western Cape    7441  Cape Town
# 3         Cape Town  Western Cape    7441  Cape Town
# 4         Cape Town  Western Cape    7139  Cape Town
#
#                    smart_location country_code       country  latitude  \
# 0  Southern Suburbs, South Africa           ZA  South Africa -33.94739
# 1         Cape Town, South Africa           ZA  South Africa -33.90771
# 2         Cape Town, South Africa           ZA  South Africa -33.80114
# 3         Cape Town, South Africa           ZA  South Africa -33.85878
# 4         Cape Town, South Africa           ZA  South Africa -34.11124
#
#    longitude is_location_exact      property_type        room_type  \
# 0   18.47600                 t         Guesthouse  Entire home/apt
# 1   18.40535                 t  Bed and breakfast       Hotel room
# 2   18.46180                 t              House  Entire home/apt
# 3   18.48970                 t          Apartment     Private room
# 4   18.82349                 t          Apartment  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             2        1.0       1.0   1.0  Real Bed
# 1             2        1.0       1.0   1.0  Real Bed
# 2             6        3.0       3.0   4.0  Real Bed
# 3             2        1.5       1.0   2.0  Real Bed
# 4             2        1.0       1.0   1.0  Real Bed
#
#                                            amenities  square_feet      price  \
# 0  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...          NaN    $661.00
# 1  {TV,Wifi,"Air conditioning",Breakfast,"Free st...        269.0  $2,105.00
# 2  {TV,"Cable TV",Internet,Wifi,"Wheelchair acces...          NaN  $2,048.00
# 3  {Internet,Wifi,"Wheelchair accessible",Pool,Ki...          NaN  $1,337.00
# 4  {TV,Kitchen,"Free parking on premises","Family...          NaN    $561.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0    $4,221.00    $16,884.00              NaN      $211.00                2
# 1          NaN           NaN            $0.00        $0.00                2
# 2    $9,000.00    $40,000.00        $2,500.00      $850.00                6
# 3          NaN    $15,684.00              NaN          NaN                2
# 4          NaN           NaN              NaN      $150.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0        $0.00               3             730                       3
# 1        $0.00               3              30                       1
# 2      $250.00               2             120                       2
# 3        $0.00               5            1125                       5
# 4      $100.00               2             730                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                     730                     730
# 1                       3                      30                      30
# 2                       2                     120                     120
# 3                       5                    1125                    1125
# 4                       2                     730                     730
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     3.0                   730.0      3 weeks ago
# 1                     1.1                    30.0            today
# 2                     2.0                   120.0      4 weeks ago
# 3                     5.0                  1125.0      2 weeks ago
# 4                     2.0                   730.0    13 months ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                2               20               50
# 1                t                0                0                0
# 2                t                0                2               32
# 3                t               12               22               52
# 4                t               26               56               86
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               319            2019-12-28                 49
# 1                 0            2019-12-29                  2
# 2               293            2019-12-29                 27
# 3               327            2019-12-28                  5
# 4               361            2019-12-29                  0
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      7   2013-05-31  2019-12-15                  97.0
# 1                      0   2011-10-24  2016-02-06                 100.0
# 2                      2   2013-12-15  2019-08-18                  97.0
# 3                      0   2013-01-06  2016-12-10                 100.0
# 4                      0          NaN         NaN                   NaN
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                    10.0                       10.0                   10.0
# 4                     NaN                        NaN                    NaN
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                 10.0
# 1                         10.0                    10.0                 10.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                          NaN                     NaN                  NaN
#
#   requires_license  license  jurisdiction_names instant_bookable  \
# 0                f      NaN                 NaN                t
# 1                f      NaN                 NaN                t
# 2                f      NaN                 NaN                f
# 3                f      NaN                 NaN                f
# 4                f      NaN                 NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     moderate
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               5
# 2                               2
# 3                               5
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            0
# 2                                            2
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             4
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.61
# 1                                            0               0.02
# 2                                            0               0.37
# 3                                            0               0.06
# 4                                            0                NaN

# %%
##----STEP TWO: Format Data----##

#a) Drop invalid rows for target
#Price is our results variable therefore drop any entries that don't have a price
#simply drop whole row with NaN in "price" column
df.dropna(subset=["price"], axis=0, inplace=True)
df.drop(df.index[5], inplace = True) #invalid row - price is way too high
# reset index, because we dropped rows
df.reset_index(drop=True, inplace=True)


# b) Replace "?" with NaN
df.replace("?", np.nan, inplace = True)
df.replace(".", np.nan, inplace = True)


# c) Find number of missing data entries in each column
missing_data = df.isnull()

for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# id
# False    24457
# Name: id, dtype: int64
#
# listing_url
# False    24457
# Name: listing_url, dtype: int64
#
# scrape_id
# False    24457
# Name: scrape_id, dtype: int64
#
# last_scraped
# False    24457
# Name: last_scraped, dtype: int64
#
# name
# False    24456
# True         1
# Name: name, dtype: int64
#
# summary
# False    23681
# True       776
# Name: summary, dtype: int64
#
# space
# False    17702
# True      6755
# Name: space, dtype: int64
#
# description
# False    24001
# True       456
# Name: description, dtype: int64
#
# experiences_offered
# False    24457
# Name: experiences_offered, dtype: int64
#
# neighborhood_overview
# False    16644
# True      7813
# Name: neighborhood_overview, dtype: int64
#
# notes
# True     13612
# False    10845
# Name: notes, dtype: int64
#
# transit
# False    15871
# True      8586
# Name: transit, dtype: int64
#
# access
# False    14167
# True     10290
# Name: access, dtype: int64
#
# interaction
# False    15202
# True      9255
# Name: interaction, dtype: int64
#
# house_rules
# False    12300
# True     12157
# Name: house_rules, dtype: int64
#
# thumbnail_url
# True    24457
# Name: thumbnail_url, dtype: int64
#
# medium_url
# True    24457
# Name: medium_url, dtype: int64
#
# picture_url
# False    24457
# Name: picture_url, dtype: int64
#
# xl_picture_url
# True    24457
# Name: xl_picture_url, dtype: int64
#
# host_id
# False    24457
# Name: host_id, dtype: int64
#
# host_url
# False    24457
# Name: host_url, dtype: int64
#
# host_name
# False    24420
# True        37
# Name: host_name, dtype: int64
#
# host_since
# False    24421
# True        36
# Name: host_since, dtype: int64
#
# host_location
# False    24311
# True       146
# Name: host_location, dtype: int64
#
# host_about
# False    13126
# True     11331
# Name: host_about, dtype: int64
#
# host_response_time
# False    19055
# True      5402
# Name: host_response_time, dtype: int64
#
# host_response_rate
# False    19055
# True      5402
# Name: host_response_rate, dtype: int64
#
# host_acceptance_rate
# True    24457
# Name: host_acceptance_rate, dtype: int64
#
# host_is_superhost
# False    24421
# True        36
# Name: host_is_superhost, dtype: int64
#
# host_thumbnail_url
# False    24421
# True        36
# Name: host_thumbnail_url, dtype: int64
#
# host_picture_url
# False    24421
# True        36
# Name: host_picture_url, dtype: int64
#
# host_neighbourhood
# True     24368
# False       89
# Name: host_neighbourhood, dtype: int64
#
# host_listings_count
# False    24421
# True        36
# Name: host_listings_count, dtype: int64
#
# host_total_listings_count
# False    24421
# True        36
# Name: host_total_listings_count, dtype: int64
#
# host_verifications
# False    24457
# Name: host_verifications, dtype: int64
#
# host_has_profile_pic
# False    24421
# True        36
# Name: host_has_profile_pic, dtype: int64
#
# host_identity_verified
# False    24421
# True        36
# Name: host_identity_verified, dtype: int64
#
# street
# False    24457
# Name: street, dtype: int64
#
# neighbourhood
# True    24457
# Name: neighbourhood, dtype: int64
#
# neighbourhood_cleansed
# False    24457
# Name: neighbourhood_cleansed, dtype: int64
#
# neighbourhood_group_cleansed
# True    24457
# Name: neighbourhood_group_cleansed, dtype: int64
#
# city
# False    24392
# True        65
# Name: city, dtype: int64
#
# state
# False    24144
# True       313
# Name: state, dtype: int64
#
# zipcode
# False    23740
# True       717
# Name: zipcode, dtype: int64
#
# market
# False    24428
# True        29
# Name: market, dtype: int64
#
# smart_location
# False    24457
# Name: smart_location, dtype: int64
#
# country_code
# False    24457
# Name: country_code, dtype: int64
#
# country
# False    24457
# Name: country, dtype: int64
#
# latitude
# False    24457
# Name: latitude, dtype: int64
#
# longitude
# False    24457
# Name: longitude, dtype: int64
#
# is_location_exact
# False    24457
# Name: is_location_exact, dtype: int64
#
# property_type
# False    24457
# Name: property_type, dtype: int64
#
# room_type
# False    24457
# Name: room_type, dtype: int64
#
# accommodates
# False    24457
# Name: accommodates, dtype: int64
#
# bathrooms
# False    24436
# True        21
# Name: bathrooms, dtype: int64
#
# bedrooms
# False    24440
# True        17
# Name: bedrooms, dtype: int64
#
# beds
# False    24389
# True        68
# Name: beds, dtype: int64
#
# bed_type
# False    24457
# Name: bed_type, dtype: int64
#
# amenities
# False    24457
# Name: amenities, dtype: int64
#
# square_feet
# True     24387
# False       70
# Name: square_feet, dtype: int64
#
# price
# False    24457
# Name: price, dtype: int64
#
# weekly_price
# True     23095
# False     1362
# Name: weekly_price, dtype: int64
#
# monthly_price
# True     23262
# False     1195
# Name: monthly_price, dtype: int64
#
# security_deposit
# False    15508
# True      8949
# Name: security_deposit, dtype: int64
#
# cleaning_fee
# False    17143
# True      7314
# Name: cleaning_fee, dtype: int64
#
# guests_included
# False    24457
# Name: guests_included, dtype: int64
#
# extra_people
# False    24457
# Name: extra_people, dtype: int64
#
# minimum_nights
# False    24457
# Name: minimum_nights, dtype: int64
#
# maximum_nights
# False    24457
# Name: maximum_nights, dtype: int64
#
# minimum_minimum_nights
# False    24457
# Name: minimum_minimum_nights, dtype: int64
#
# maximum_minimum_nights
# False    24457
# Name: maximum_minimum_nights, dtype: int64
#
# minimum_maximum_nights
# False    24457
# Name: minimum_maximum_nights, dtype: int64
#
# maximum_maximum_nights
# False    24457
# Name: maximum_maximum_nights, dtype: int64
#
# minimum_nights_avg_ntm
# False    24457
# Name: minimum_nights_avg_ntm, dtype: int64
#
# maximum_nights_avg_ntm
# False    24457
# Name: maximum_nights_avg_ntm, dtype: int64
#
# calendar_updated
# False    24457
# Name: calendar_updated, dtype: int64
#
# has_availability
# False    24457
# Name: has_availability, dtype: int64
#
# availability_30
# False    24457
# Name: availability_30, dtype: int64
#
# availability_60
# False    24457
# Name: availability_60, dtype: int64
#
# availability_90
# False    24457
# Name: availability_90, dtype: int64
#
# availability_365
# False    24457
# Name: availability_365, dtype: int64
#
# calendar_last_scraped
# False    24457
# Name: calendar_last_scraped, dtype: int64
#
# number_of_reviews
# False    24457
# Name: number_of_reviews, dtype: int64
#
# number_of_reviews_ltm
# False    24457
# Name: number_of_reviews_ltm, dtype: int64
#
# first_review
# False    16485
# True      7972
# Name: first_review, dtype: int64
#
# last_review
# False    16485
# True      7972
# Name: last_review, dtype: int64
#
# review_scores_rating
# False    15981
# True      8476
# Name: review_scores_rating, dtype: int64
#
# review_scores_accuracy
# False    15970
# True      8487
# Name: review_scores_accuracy, dtype: int64
#
# review_scores_cleanliness
# False    15973
# True      8484
# Name: review_scores_cleanliness, dtype: int64
#
# review_scores_checkin
# False    15969
# True      8488
# Name: review_scores_checkin, dtype: int64
#
# review_scores_communication
# False    15971
# True      8486
# Name: review_scores_communication, dtype: int64
#
# review_scores_location
# False    15967
# True      8490
# Name: review_scores_location, dtype: int64
#
# review_scores_value
# False    15963
# True      8494
# Name: review_scores_value, dtype: int64
#
# requires_license
# False    24457
# Name: requires_license, dtype: int64
#
# license
# True     24425
# False       32
# Name: license, dtype: int64
#
# jurisdiction_names
# True    24457
# Name: jurisdiction_names, dtype: int64
#
# instant_bookable
# False    24457
# Name: instant_bookable, dtype: int64
#
# is_business_travel_ready
# False    24457
# Name: is_business_travel_ready, dtype: int64
#
# cancellation_policy
# False    24457
# Name: cancellation_policy, dtype: int64
#
# require_guest_profile_picture
# False    24457
# Name: require_guest_profile_picture, dtype: int64
#
# require_guest_phone_verification
# False    24457
# Name: require_guest_phone_verification, dtype: int64
#
# calculated_host_listings_count
# False    24457
# Name: calculated_host_listings_count, dtype: int64
#
# calculated_host_listings_count_entire_homes
# False    24457
# Name: calculated_host_listings_count_entire_homes, dtype: int64
#
# calculated_host_listings_count_private_rooms
# False    24457
# Name: calculated_host_listings_count_private_rooms, dtype: int64
#
# calculated_host_listings_count_shared_rooms
# False    24457
# Name: calculated_host_listings_count_shared_rooms, dtype: int64
#
# reviews_per_month
# False    16485
# True      7972
# Name: reviews_per_month, dtype: int64

# %%
##----Correct Data Formats and Types----##

#change formatting of monetary amounts
df["price"] = df["price"].str.replace('$', '')
df["price"] = df["price"].str.replace(',', '')
df["cleaning_fee"] = df["cleaning_fee"].str.replace('$', '')
df["cleaning_fee"] = df["cleaning_fee"].str.replace(',', '')
df["security_deposit"] = df["security_deposit"].str.replace('$', '')
df["security_deposit"] = df["security_deposit"].str.replace(',', '')
df["extra_people"] = df["extra_people"].str.replace('$', '')
df["extra_people"] = df["extra_people"].str.replace(',', '')
df["host_response_rate"] = df["host_response_rate"].str.replace('%', '')
df['zipcode'] = df['zipcode'].str.replace('Po Box', '')
df['zipcode'] = df['zipcode'].str.replace('Green Point', '')
df[["id", "host_id"]] = df[["id", "host_id"]].astype("object") #we do not want an average of IDs
df[["price", "cleaning_fee", "security_deposit", "extra_people", "host_response_rate"]] = df[["price", "cleaning_fee", "security_deposit", "extra_people", "host_response_rate"]].astype("float") #change from string to float

# %%
##----Process Binary Features----##

#change binary t/f columns to 0 and 1
columns =  ['has_availability', 'host_is_superhost', 'host_identity_verified', 'host_has_profile_pic',
                   'is_location_exact', 'requires_license', 'instant_bookable',
                   'require_guest_profile_picture', 'require_guest_phone_verification', 'is_business_travel_ready']
for c in columns:
    df[c] = df[c].replace('f',0,regex=True)
    df[c] = df[c].replace('t',1,regex=True)

# %%
##----Remove Features exceeding Threshold of Missing Values----##

#Determine which features have missing values exceeding threshold (>50% missing)
above_thresh = [] #need to remove feature
below_thresh = [] #use imputations
missing = []
for column in missing_data.columns.values.tolist():
    missing_data_counts = missing_data[column].value_counts()
    if(len(missing_data_counts) > 1):
        missing.append(column)
        if((missing_data_counts[1]/(missing_data_counts[0]+missing_data_counts[1])) > 0.5): 
            above_thresh.append(column)
        else:
            below_thresh.append(column)
    else:
        below_thresh.append(column)  
print("Above", above_thresh)
print("")
print("Below", below_thresh)
print("")
print("Missing", missing)
# Out:
# Above ['notes', 'host_neighbourhood', 'square_feet', 'weekly_price', 'monthly_price', 'license']
#
# Below ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'street', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market', 'smart_location', 'country_code', 'country', 'latitude', 'longitude', 'is_location_exact', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'requires_license', 'jurisdiction_names', 'instant_bookable', 'is_business_travel_ready', 'cancellation_policy', 'require_guest_profile_picture', 'require_guest_phone_verification', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']
#
# Missing ['name', 'summary', 'space', 'description', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_has_profile_pic', 'host_identity_verified', 'city', 'state', 'zipcode', 'market', 'bathrooms', 'bedrooms', 'beds', 'square_feet', 'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'license', 'reviews_per_month']

# %%
##--Drop columns with too many missing values--##
uncorr_columns = ['host_neighbourhood', 'square_feet', 'weekly_price', 'monthly_price', 'license']
df = df.drop(uncorr_columns, axis=1)

# %%
##----Imputation----##

#For features below threshold
#Separate into continuous, discrete and categorical
cont = ['security_deposit', 'cleaning_fee', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month']
discrete = ['bathrooms', 'bedrooms', 'beds', 'host_listings_count', 'host_total_listings_count']
category = ['host_response_time', 'zipcode', 'host_is_superhost', 'host_has_profile_pic', 'host_identity_verified']
cont = list(cont) 
discrete = list(discrete)
category = list(category)

#Replace continuous numerical variables with mean
for column in cont:
    avg = df[column].astype("float").mean(axis=0) 
    df[column] = df[column].replace(np.nan, avg)

#Replace discrete numerical variables with median
for column in discrete:
    med = df[column].astype("float").median(axis=0) 
    df[column] = df[column].replace(np.nan, med)

#Replace discrete categorical variables with mode
for column in category:
    mode = df[column].mode() 
    df[column] = df[column].replace(np.nan, mode[0])

# %%
##--Handling Outliers--##

#1. Std. dev.
avg_price = df['price'].astype("float").mean(axis=0) 
std_dev = df['price'].astype("float").std(axis= 0)
outliers = []
remainder_std = []
threshold = avg_price + 4*std_dev #originally 3 std dev
print("Threshold for Outliers: R",threshold)
for entry in df["price"]:
    if(entry > threshold):
        outliers.append(entry)
    else:
        remainder_std.append(entry)
print("Number of outliers: ", len(outliers))
# Out:
# Threshold for Outliers: R 29925.8169852753
# Number of outliers:  150

# %%
sns_plot=sns.distplot(remainder_std);
sns_plot.set(xlabel = "Price", ylabel = "Frequency")
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Price')]

# %%
#2. 99th percentile
percentile_price = df['price'].quantile(.99)
print("Threshold for Outliers: R",percentile_price)
outliers_percentile = []
remainder = []
for entry in df["price"]:
    if(entry > percentile_price):
        outliers_percentile.append(entry)
    else:
        remainder.append(entry)
print("Number of outliers: ", len(outliers_percentile))
# Out:
# Threshold for Outliers: R 21628.799999999614
# Number of outliers:  245

# %%
##----Remove/Retain Outliers----##

df = df.loc[~(df['price'] == 0)] #Remove rows with price value of zero (target)

#If remove_outliers is set at top of notebook
if(remove_outliers):
    df = df.loc[(df['price'] < percentile_price)] #remove outliers according to 99th percentile

# %%
##----Plot Distribution of Target Price Data----##

sns_plot=sns.distplot(df["price"]);
sns_plot.set(xlabel = "Price", ylabel = "Frequency")
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Price')]

# %%
##----STEP THREE: Reducing Skewness----##

#Log Transform
df["log_price"] = np.log(df["price"])
sns_plot=sns.distplot(df["log_price"]);
sns_plot.set(xlabel = "Log Price", ylabel = "Frequency")
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Log Price')]

# %%
sns_plot.figure.savefig("log_dist.png", dpi=200) #save plot

# %%
##----Probability Plot----##
ax1 =  pyplot.subplot(221)
stats.probplot(df["price"], dist=stats.norm, plot=ax1)
ax2 =  pyplot.subplot(222)
stats.probplot(df["log_price"], dist=stats.norm, plot=ax2)
# Out:
# ((array([-4.02616583, -3.81241691, -3.69555592, ...,  3.69555592,
#           3.81241691,  4.02616583]),
#   array([ 4.83628191,  4.83628191,  4.84418709, ..., 12.4291882 ,
#          12.51721609, 12.61153109])),
#  (0.9201770991795508, 7.1415246728328405, 0.9803056901391629))

# %%
##----BoxCox Transform----##
boxcox_price, val =  stats.boxcox(df["price"])
print(val)
sns_plot = sns.distplot(boxcox_price);
sns_plot.set(xlabel = "BoxCox Price", ylabel = "Frequency")
# Out:
# -0.2741296911628269
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'BoxCox Price')]

# %%
sns_plot.figure.savefig("boxcox_dist.png", dpi=200) #save plot

# %%
##----Probability Plot----##
ax1 =  pyplot.subplot(221)
stats.probplot(df["price"], dist=stats.norm, plot=ax1)
ax2 =  pyplot.subplot(222)
stats.probplot(boxcox_price, dist=stats.norm, plot=ax2)
# Out:
# ((array([-4.02616583, -3.81241691, -3.69555592, ...,  3.69555592,
#           3.81241691,  4.02616583]),
#   array([2.67902838, 2.67902838, 2.68112571, ..., 3.52704031, 3.52992207,
#          3.53293346])),
#  (0.1254367369408334, 3.1167629989927503, 0.9993421779400101))

# %%
##----Square Root Transform----##
#weakest transform
sqrt_price =  np.sqrt(df["price"])
sns_plot = sns.distplot(sqrt_price);
sns_plot.set(xlabel = "Sqrt Price", ylabel = "Frequency")
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Sqrt Price')]

# %%
sns_plot.figure.savefig("sqrt_dist.png", dpi=200) #save plot

# %%
##----Probability Plot----##
ax1 =  pyplot.subplot(221)
stats.probplot(df["price"], dist=stats.norm, plot=ax1)
ax2 =  pyplot.subplot(222)
stats.probplot(sqrt_price, dist=stats.norm, plot=ax2)
# Out:
# ((array([-4.02616583, -3.81241691, -3.69555592, ...,  3.69555592,
#           3.81241691,  4.02616583]),
#   array([ 11.22497216,  11.22497216,  11.26942767, ..., 499.99299995,
#          522.49114825, 547.72073176])),
#  (21.803993209296696, 40.448312973172605, 0.7996109161794517))

# %%
##----STEP FOUR: Binning----##

# Bin into four categories
df["host_response_rate"] = pd.cut(df["host_response_rate"], bins=[0, 50, 90, 99, 100], labels=['0-49%', '50-89%', '90-99%', '100%'], include_lowest=True)

# Converting to string
df["host_response_rate"] = df["host_response_rate"].astype('str')

# Replace nulls with 'unknown'
df["host_response_rate"].replace('nan', 'unknown', inplace=True)

# Category counts
df["host_response_rate"].value_counts()
# Out:
# 100%       14807
# unknown     5400
# 50-89%      2179
# 0-49%       1087
# 90-99%       979
# Name: host_response_rate, dtype: int64

# %%
##----One Hot Encoding----##
dummy_variable_1=pd.get_dummies(df["host_response_rate"])
df = pd.concat([df, dummy_variable_1], axis=1)

# %%
df = df.rename(index=str, columns={"calculated_host_listings_count_private_rooms": "host_count_private", "calculated_host_listings_count_entire_homes":"host_count_entire"})

# %%
##----Drop unhelpful columns----##
uncorr_columns = ['listing_url', 'scrape_id', 'last_scraped', 'host_total_listings_count', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_location', 'host_thumbnail_url', 'host_picture_url', 'host_verifications', 'calendar_last_scraped', 'street', 'neighbourhood', 'neighbourhood_group_cleansed', 'city', 'state', 'market', 'smart_location', 'calendar_updated', 'host_acceptance_rate', 'first_review', 'last_review', 'jurisdiction_names']
df = df.drop(uncorr_columns, axis=1)

# %%
df.to_csv("1-Cleaned Data.csv", index=False) #save cleaned data
